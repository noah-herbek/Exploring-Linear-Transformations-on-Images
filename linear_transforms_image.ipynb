# %% [markdown]
# # __Exploring Linear Transformations on Images:__
# MA 2071: Linear Algebra Project
# Noah Herbek, Marnix Adriaanse, Spring 2025

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# %% [markdown]
# First, we load the image
#
# - You can download an image from https://github.com/noah-herbek/Exploring-Linear-Transformations-on-Images/blob/main/spencer.jpg

# %% [markdown]
# # ___Setup:___
#
# - Next, we can define the function that makes the linear transfromations with 5 inputs. Input 1 being the image and the other for coming from the matrix we want the image transforned onto.

# %%
def image_transform(image, a, b, c, d):

    image_np = np.array(image)
    height, width, channels = image_np.shape
    center_x, center_y = width / 2, height / 2
    transformed_image = np.zeros_like(image_np)
    
    linear_transform = np.array([[a, b], [c, d]])  # Create matrix from inputs
    
    for y in range(height):
        for x in range(width):
            # Translate to origin and apply transform
            translated = np.array([x - center_x, -(y - center_y)])
            transformed = linear_transform @ translated
            
            # Translate back and round
            new_x = int(round(transformed[0] + center_x))
            new_y = int(round(-transformed[1] + center_y))
            
            # Copy pixel if within bounds
            if 0 <= new_x < width and 0 <= new_y < height:
                transformed_image[new_y, new_x] = image_np[y, x]
    
    return transformed_image

# %% [markdown]
# - Another thing to define is a function that simply displays the image onto the screen.

# %%
def showimage(wantedimage):
    plt.imshow(Image.fromarray(wantedimage))
    plt.show()

# %% [markdown]
# - With the last item in setpu, we want to set our image as image0, turn it into an array, show the dimentions, and display the image.

# %%
image0 = Image.open("spencer.jpg")
image0_np = np.array(image0)
print(f'The dimension of the image_np is {image0_np.shape}')
showimage(image0_np)
# Out:
# The dimension of the image_np is (970, 970, 3)

# %% [markdown]
# # ___Linear Transformations___
#
# ___Linear Transformation 1:___
#
# - For the first transfromation, "Construct a linear transformation that scales image0 to half its size, and name it image1". In order to do that, we can take the identity matrix, and mulitply it by a scaler of 1/2![image.png](attachment:image.png)

# %%
#Linear Transformation 1
image1 = image_transform(image0, 1/2, 0, 0, 1/2)
showimage(image1)

# %% [markdown]
# ___Linear Transformation 2:___
#
# - For the second transfromation, "Construct a linear transformation that reflects image1 through the line y = 2x. Name the resulting image image2". In order to do that, we can take general fromula to find a reflection matrix over a line y=mx, with m=2. With this we find out answer by doing some simply math. ![image.png](attachment:image.png)

# %%
#Linear Transformation 2
image2 = image_transform(image0, -3/5, 4/5, 4/5, 3/5)
showimage(image2)

# %% [markdown]
# ___Linear Transformation 3:___
#
# - For the third transfromation, "Construct a linear transformation that reflects image1 through the line y = -1/2x. Name the resulting image image3". In order to do that, we can take general fromula to find a reflection matrix over a line y=mx, with m=2.With this we find out answer by doing some simply math. ![image.png](attachment:image.png)

# %%
#Linear Transformation 3
image3 = image_transform(image0, 3/5, -4/5, -4/5, -3/5)
showimage(image3)

# %% [markdown]
# ___Linear Transformation 4:___
#
# - For the fourth transfromation, "Find the standard matrix of the linear transformation T = T2 ◦ T1. Apply T to image1 and print the resulting image". In order to do that, we can our two transformations from before and multiply them together.![image.png](attachment:image.png)

# %%
#Linear Transformation 4
image1 = image_transform(image1, -3/5, 4/5, 4/5, 3/5)
showimage(image1)

# %% [markdown]
# ___Linear Transformation 5:___
#
# - For the fifth transfromation, "T−1: Find the standard matrix of the inverse transformation of T. Apply T−1 to image3 and print the resulting image". In order to do that, we can take the transfromation that we did to image3, and with that make and agumented matrix with the identity matrix in order to get a new matix that can use to transfrom image3 back to the orginal.![image.png](attachment:image.png)

# %%
#Linear Transformation 5
image3 = image_transform(image3, 3/5, -4/5, -4/5, -3/5)
showimage(image3)

# %% [markdown]
# ___Linear Transformation 6:___
#
# - For the last transfromation, "Construct your favorite linear transformation and apply it to image1. You may use a composition of shearing, rotation, or any other transformation you prefer. Name the resulting image image4. Find the standard matrix of your transformation and print image4". I went with a little sheering of the image. ![image.png](attachment:image.png)

# %%
#Linear Transformation 6
image4 = image_transform(image1, 0, 1, 0.5, 1)
showimage(image4)
